# %%
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
#for hyper parameter tuning

import logging
en=pd.read_csv('/content/drive/MyDrive/Dataset/Emotional_H/english.csv')
es=pd.read_csv('/content/drive/MyDrive/Dataset/Emotional_H/spanish.csv')
df=pd.read_csv('/content/drive/MyDrive/Dataset/Emotional_H/deepfake.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
en1= pd.concat([en, es], axis=0)

# %%
en.head()
# Out:
#            0           1          2          3          4          5  \
# 0 -292.09140  107.465470 -44.139664  44.164894 -17.887180 -12.471088
# 1 -318.74023   95.526634 -39.401190  27.715158 -22.705025  -6.303997
# 2 -315.53300   92.288320 -40.423940  34.508945 -18.966896  -4.724031
# 3 -301.56680   83.467590 -43.062504  54.350730 -23.995485   0.010661
# 4 -370.59442  111.891780  17.380352  15.352755  20.350155  -5.587485
#
#           6          7         8          9  ...        30        31  \
# 0 -3.590851  -7.044466 -7.811891  -6.014476  ... -3.393049 -5.738670
# 1 -8.845734  -5.550812 -3.317510 -11.346023  ... -3.222558 -2.474380
# 2 -8.200342 -17.788260 -7.930902  -5.146730  ... -4.448881 -3.247578
# 3 -7.562350  -6.149078 -7.499183  -4.696762  ... -3.844912 -3.790015
# 4  2.570047  -5.771169  0.900893   1.253922  ... -3.528444 -1.668683
#
#          32        33        34        35        36        37        38  \
# 0 -5.255382 -1.789235 -2.641787  0.179766  2.768640  4.179280  6.194175
# 1 -3.832746 -0.532228  0.773945 -2.555231  1.881754  1.472017  3.019983
# 2 -5.742671 -3.982553 -1.573804 -2.270712  2.832158  2.902952  4.061225
# 3 -5.441263 -4.541252 -1.572427 -4.257127  0.672187  1.667025  4.608165
# 4 -5.351765 -2.553765 -4.650506 -4.515150 -2.736658 -2.733803 -2.883491
#
#          39
# 0  6.816234
# 1  5.518497
# 2  5.034604
# 3  6.336764
# 4 -1.746059
#
# [5 rows x 40 columns]

# %%
df.head()
# Out:
#            0          1          2          3          4         5          6  \
# 0 -384.56560  41.313190 -22.512484   9.647027  -2.853703 -3.265914  -3.560151
# 1 -223.81729  56.277252 -44.560738  30.841774  -6.800030 -9.480381 -12.553636
# 2 -287.55120  38.495940 -46.022034  -4.306948 -39.552410 -0.064860  -1.571697
# 3 -283.81073  78.969185 -44.129803  34.145170 -33.359930 -0.670134 -29.290794
# 4 -314.64250  65.129330 -39.895107  46.261517 -27.292423 -3.164591 -28.973036
#
#           7          8          9  ...        30        31        32  \
# 0  1.136599  -6.335774   2.084825  ... -1.918954  0.837745 -0.662066
# 1 -2.488934 -20.258568   1.055871  ... -1.938011 -0.318601 -2.191073
# 2  0.129822  -6.651174   0.442882  ... -1.395410  2.495563  0.403445
# 3  2.737740 -13.425995  -9.304039  ...  2.683249 -0.263922 -0.916600
# 4  2.349446 -11.545103 -14.825808  ...  1.965076  0.952093  0.326784
#
#          33        34        35        36        37        38        39
# 0  1.022848  0.352392  1.674392  1.557137  3.480937  3.655131  4.517235
# 1 -0.846907 -0.599855 -0.128816 -0.673368  1.305002  0.397836  1.175030
# 2  0.287585 -0.272511 -2.372126 -1.631154  2.808672  0.088064  3.085620
# 3  0.135817  0.230657 -1.542825  1.075186 -0.209143 -0.290686  2.055822
# 4  1.249048  2.197192  0.238264  1.979593  0.817636  0.773652  2.356442
#
# [5 rows x 40 columns]

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

# %%
def autoencoder(data,test):
  data['label']=0
  test['label']=1
  X_train, X_test =train_test_split(data,test_size=0.2,random_state=42)
  X_train1=X_train[X_train['label']==0]
  X_test=pd.concat([X_test,test],ignore_index=True)
  X_train1=X_train1.drop(['label'],axis=1)
  X_train=X_train.drop(['label'],axis=1)
  y_test=X_test['label']
  X_test=X_test.drop(['label'],axis=1)
  input_dim = X_train.shape[1]
  encoding_dim = 100
  input_layer = Input(shape=(input_dim, ))
  encoder = Dense(encoding_dim, activation="tanh",
                  activity_regularizer=regularizers.l1(10e-5))(input_layer)
  encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)

  decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
  decoder = Dense(input_dim, activation='relu')(decoder)
  autoencoder = Model(inputs=input_layer, outputs=decoder)


  nb_epoch = 30
  batch_size = 16

  autoencoder.compile(optimizer='adam',
                      loss='mean_squared_error',
                      metrics=['accuracy'])

  checkpointer = ModelCheckpoint(filepath="model.h5",
                                verbose=0,
                                save_best_only=True)
  tensorboard = TensorBoard(log_dir='./logs',
                            histogram_freq=0,
                            write_graph=True,
                            write_images=True)

  history = autoencoder.fit(X_train1, X_train1,
                      epochs=nb_epoch,
                      batch_size=batch_size,
                      shuffle=True,
                      validation_data=(X_test, X_test),
                      verbose=1,
                      callbacks=[checkpointer, tensorboard]).history
  predictions = autoencoder.predict(X_test)


  mse = np.mean(np.power(X_test - predictions, 2), axis=1)
  error_df = pd.DataFrame({'reconstruction_error': mse,
                          'true_class': y_test})
  return error_df,y_test

# %%
def plot(error_df,threshold):
  groups = error_df.groupby('true_class')
  fig, ax = plt.subplots()

  for name, group in groups:
      ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
              label= "Synthetic Ai voice" if name == 1 else "Real User Voice")
  ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
  ax.legend()
  plt.title("Reconstruction error for different classes")
  plt.ylabel("Reconstruction error")
  plt.xlabel("Data point index")
  plt.show();

# %%
en
# Out:
#                0           1          2          3          4          5  \
# 0     -292.09140  107.465470 -44.139664  44.164894 -17.887180 -12.471088
# 1     -318.74023   95.526634 -39.401190  27.715158 -22.705025  -6.303997
# 2     -315.53300   92.288320 -40.423940  34.508945 -18.966896  -4.724031
# 3     -301.56680   83.467590 -43.062504  54.350730 -23.995485   0.010661
# 4     -370.59442  111.891780  17.380352  15.352755  20.350155  -5.587485
# ...          ...         ...        ...        ...        ...        ...
# 38500 -495.41122   96.029040  26.291607  40.261074   1.995508  -7.475473
# 38501 -431.63214   83.030200   9.887699  41.564945  -1.259784  -5.822345
# 38502 -373.61176   87.108925  -2.676391  38.697700   1.002508   3.059598
# 38503 -345.88022  101.155450 -25.766783  47.718010  13.056614  -5.033289
# 38504 -392.34213  100.674576   0.363496  34.335873   3.059788   4.620662
#
#                6          7          8          9  ...        30        31  \
# 0      -3.590851  -7.044466  -7.811891  -6.014476  ... -3.393049 -5.738670
# 1      -8.845734  -5.550812  -3.317510 -11.346023  ... -3.222558 -2.474380
# 2      -8.200342 -17.788260  -7.930902  -5.146730  ... -4.448881 -3.247578
# 3      -7.562350  -6.149078  -7.499183  -4.696762  ... -3.844912 -3.790015
# 4       2.570047  -5.771169   0.900893   1.253922  ... -3.528444 -1.668683
# ...          ...        ...        ...        ...  ...       ...       ...
# 38500 -15.441088  -0.622967 -18.742676  -8.996840  ... -2.360138  0.873679
# 38501 -10.120617  -2.751728 -12.610564  -9.727573  ... -0.496728  2.215880
# 38502 -14.857136   0.876030 -20.916245  -0.103694  ... -0.220531 -2.968776
# 38503 -12.884117 -10.463828 -12.427376  -0.638391  ... -2.836385 -3.059580
# 38504 -21.928724   4.238646  -9.126817  -1.151136  ...  1.442476 -7.200326
#
#              32        33        34        35        36        37        38  \
# 0     -5.255382 -1.789235 -2.641787  0.179766  2.768640  4.179280  6.194175
# 1     -3.832746 -0.532228  0.773945 -2.555231  1.881754  1.472017  3.019983
# 2     -5.742671 -3.982553 -1.573804 -2.270712  2.832158  2.902952  4.061225
# 3     -5.441263 -4.541252 -1.572427 -4.257127  0.672187  1.667025  4.608165
# 4     -5.351765 -2.553765 -4.650506 -4.515150 -2.736658 -2.733803 -2.883491
# ...         ...       ...       ...       ...       ...       ...       ...
# 38500  1.215226 -0.870670  2.555632  1.189418  1.889585  1.558453  2.055741
# 38501  1.000547 -0.314262  3.038537 -0.010879 -0.184066  1.502149 -0.663567
# 38502  0.365699 -0.097024  0.817772  0.684853  5.024533  2.360990  4.233398
# 38503 -0.565986 -1.049126  1.258685  0.547962  1.794619  0.846993  4.208682
# 38504 -0.036158 -3.444256 -2.563124  2.237817 -0.690503  2.843204  4.329068
#
#              39
# 0      6.816234
# 1      5.518497
# 2      5.034604
# 3      6.336764
# 4     -1.746059
# ...         ...
# 38500  4.356979
# 38501  3.008308
# 38502  5.135082
# 38503  4.897294
# 38504  5.540017
#
# [38505 rows x 40 columns]

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
scalar=MinMaxScaler()
enf=pd.DataFrame(scalar.fit_transform(en1),columns=en1.columns)
df1=pd.DataFrame(scalar.fit_transform(df),columns=df.columns)

# %%
[e,y_test]=autoencoder(enf,df1)
# Out:
# Epoch 1/30
# 2358/2358 [==============================] - 9s 3ms/step - loss: 0.0300 - accuracy: 0.5868 - val_loss: 0.0179 - val_accuracy: 0.7741
# Epoch 2/30
#   74/2358 [..............................] - ETA: 4s - loss: 0.0175 - accuracy: 0.8007
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2358/2358 [==============================] - 7s 3ms/step - loss: 0.0142 - accuracy: 0.8302 - val_loss: 0.0097 - val_accuracy: 0.8466
# Epoch 3/30
# 2358/2358 [==============================] - 6s 2ms/step - loss: 0.0095 - accuracy: 0.8798 - val_loss: 0.0095 - val_accuracy: 0.8951
# Epoch 4/30
# 2358/2358 [==============================] - 8s 3ms/step - loss: 0.0094 - accuracy: 0.9013 - val_loss: 0.0095 - val_accuracy: 0.8672
# Epoch 5/30
# 2358/2358 [==============================] - 6s 3ms/step - loss: 0.0094 - accuracy: 0.8983 - val_loss: 0.0094 - val_accuracy: 0.8715
# Epoch 6/30
# 2358/2358 [==============================] - 8s 3ms/step - loss: 0.0093 - accuracy: 0.8983 - val_loss: 0.0093 - val_accuracy: 0.8784
# Epoch 7/30
# 2358/2358 [==============================] - 6s 3ms/step - loss: 0.0093 - accuracy: 0.8971 - val_loss: 0.0093 - val_accuracy: 0.8761
# Epoch 8/30
# 2358/2358 [==============================] - 8s 3ms/step - loss: 0.0093 - accuracy: 0.8952 - val_loss: 0.0093 - val_accuracy: 0.8810
# Epoch 9/30
# 2358/2358 [==============================] - 6s 2ms/step - loss: 0.0093 - accuracy: 0.8941 - val_loss: 0.0093 - val_accuracy: 0.8855
# Epoch 10/30
# 2358/2358 [==============================] - 7s 3ms/step - loss: 0.0092 - accuracy: 0.8949 - val_loss: 0.0093 - val_accuracy: 0.8841
# Epoch 11/30
# 2358/2358 [==============================] - 7s 3ms/step - loss: 0.0092 - accuracy: 0.8940 - val_loss: 0.0092 - val_accuracy: 0.9026
# Epoch 12/30
# 2358/2358 [==============================] - 8s 3ms/step - loss: 0.0092 - accuracy: 0.8906 - val_loss: 0.0092 - val_accuracy: 0.8738
# Epoch 13/30
# 2358/2358 [==============================] - 7s 3ms/step - loss: 0.0092 - accuracy: 0.8942 - val_loss: 0.0092 - val_accuracy: 0.8774
# Epoch 14/30
# 2358/2358 [==============================] - 7s 3ms/step - loss: 0.0092 - accuracy: 0.8900 - val_loss: 0.0092 - val_accuracy: 0.8565
# Epoch 15/30
# 2358/2358 [==============================] - 6s 3ms/step - loss: 0.0092 - accuracy: 0.8910 - val_loss: 0.0092 - val_accuracy: 0.8875
# Epoch 16/30
# 2358/2358 [==============================] - 7s 3ms/step - loss: 0.0092 - accuracy: 0.8919 - val_loss: 0.0092 - val_accuracy: 0.8861
# Epoch 17/30
# 2358/2358 [==============================] - 7s 3ms/step - loss: 0.0092 - accuracy: 0.8912 - val_loss: 0.0093 - val_accuracy: 0.8024
# Epoch 18/30
# 2358/2358 [==============================] - 7s 3ms/step - loss: 0.0092 - accuracy: 0.8899 - val_loss: 0.0092 - val_accuracy: 0.8651
# Epoch 19/30
# 2358/2358 [==============================] - 6s 3ms/step - loss: 0.0092 - accuracy: 0.8912 - val_loss: 0.0092 - val_accuracy: 0.8586
# Epoch 20/30
# 2358/2358 [==============================] - 7s 3ms/step - loss: 0.0092 - accuracy: 0.8904 - val_loss: 0.0092 - val_accuracy: 0.8617
# Epoch 21/30
# 2358/2358 [==============================] - 9s 4ms/step - loss: 0.0092 - accuracy: 0.8925 - val_loss: 0.0092 - val_accuracy: 0.8911
# Epoch 22/30
# 2358/2358 [==============================] - 7s 3ms/step - loss: 0.0054 - accuracy: 0.8959 - val_loss: 1.0977e-04 - val_accuracy: 0.9543
# Epoch 23/30
# 2358/2358 [==============================] - 7s 3ms/step - loss: 1.0536e-04 - accuracy: 0.9449 - val_loss: 1.1057e-04 - val_accuracy: 0.9393
# Epoch 24/30
# 2358/2358 [==============================] - 7s 3ms/step - loss: 1.0064e-04 - accuracy: 0.9474 - val_loss: 1.9550e-04 - val_accuracy: 0.9218
# Epoch 25/30
# 2358/2358 [==============================] - 9s 4ms/step - loss: 9.9515e-05 - accuracy: 0.9469 - val_loss: 1.8313e-04 - val_accuracy: 0.9166
# Epoch 26/30
# 2358/2358 [==============================] - 7s 3ms/step - loss: 9.8314e-05 - accuracy: 0.9497 - val_loss: 1.0451e-04 - val_accuracy: 0.9465
# Epoch 27/30
# 2358/2358 [==============================] - 8s 4ms/step - loss: 9.7039e-05 - accuracy: 0.9464 - val_loss: 1.0955e-04 - val_accuracy: 0.9466
# Epoch 28/30
# 2358/2358 [==============================] - 7s 3ms/step - loss: 9.6082e-05 - accuracy: 0.9458 - val_loss: 9.5263e-05 - val_accuracy: 0.9637
# Epoch 29/30
# 2358/2358 [==============================] - 8s 3ms/step - loss: 9.4039e-05 - accuracy: 0.9491 - val_loss: 1.1209e-04 - val_accuracy: 0.9308
# Epoch 30/30
# 2358/2358 [==============================] - 9s 4ms/step - loss: 9.3338e-05 - accuracy: 0.9477 - val_loss: 1.0139e-04 - val_accuracy: 0.9480
# 296/296 [==============================] - 0s 1ms/step

# %%
plot(e,0.0002)

# %%
plot(e,0.008)

# %%
from sklearn.metrics import confusion_matrix

# %%
def cf(error_df,threshold):
  y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
  conf_matrix = confusion_matrix(y_test, y_pred)
  LABELS = ["User1", "User2"]
  plt.figure(figsize=(12, 12))
  sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
  plt.title("Confusion matrix")
  plt.ylabel('True class')
  plt.xlabel('Predicted class')
  plt.show()

# %%
cf(e,0.0002)
